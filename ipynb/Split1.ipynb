# %% [markdown]
# # ```Split-1```

# %% [markdown]
# # Training

# %%
import gc
import torch

gc.collect()  # Force garbage collection to free up memory
torch.cuda.empty_cache()  # Optional but can help reduce memory pressure

# %%
import os
import warnings

# Ignore the specific warning about FlashAttention
warnings.filterwarnings(
    "ignore", 
    message="1Torch was not compiled with flash attention."
)

split = 1
result_path=f'./Split{split}_results'
os.makedirs(result_path, exist_ok=True)

# %%
from main import loop

# %%
test_accs_top1, test_accs_top5 = loop(root="frames", 
                                        index_cache="frames_index.txt", 
                                        splits_file="splits.pkl", 
                                        get_splits=[f"split{split}_train", f"split{split}_test"], 
                                        epochs=30,
                                        Is_train=True, 
                                        local_model_path=False, 
                                        model_name=f'Split{split}', 
                                        mapping=False)
# Out:
# PyTorch Version: 2.3.1+cu118
# CUDA Available: True
# CUDA Version: 11.8
# cuDNN Version: 8700
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# VisionTransformer (VisionTransformer)                        [1, 3, 384, 384]     [1, 19]              768                  Partial
# ├─Conv2d (conv_proj)                                         [1, 3, 384, 384]     [1, 768, 24, 24]     (590,592)            False
# ├─Encoder (encoder)                                          [1, 577, 768]        [1, 577, 768]        443,136              Partial
# │    └─Dropout (dropout)                                     [1, 577, 768]        [1, 577, 768]        --                   --
# │    └─Sequential (layers)                                   [1, 577, 768]        [1, 577, 768]        --                   Partial
# │    │    └─EncoderBlock (encoder_layer_0)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_1)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_2)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_3)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_4)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_5)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_6)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_7)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_8)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_9)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_10)                  [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_11)                  [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    └─LayerNorm (ln)                                        [1, 577, 768]        [1, 577, 768]        1,536                True
# ├─Sequential (heads)                                         [1, 768]             [1, 19]              --                   True
# │    └─Dropout (0)                                           [1, 768]             [1, 768]             --                   --
# │    └─Linear (1)                                            [1, 768]             [1, 19]              14,611               True
# ============================================================================================================================================
# Total params: 86,105,107
# Trainable params: 56,719,123
# Non-trainable params: 29,385,984
# Total mult-adds (M): 396.90
# ============================================================================================================================================
# Input size (MB): 1.77
# Forward/backward pass size (MB): 304.87
# Params size (MB): 229.25
# Estimated Total Size (MB): 535.89
# ============================================================================================================================================
# Model loaded to cuda
# Loading samples from cache: frames_index.txt
#
# --- DEBUG: Total samples loaded into FrameDataset: 577552 ---
# Number of classes in dataset: 19 {'cut_tomato': 0, 'place_tomato_into_bowl': 1, 'cut_cheese': 2, 'place_cheese_into_bowl': 3, 'cut_lettuce': 4, 'place_lettuce_into_bowl': 5, 'add_salt': 6, 'add_vinegar': 7, 'add_oil': 8, 'add_pepper': 9, 'mix_dressing': 10, 'peel_cucumber': 11, 'cut_cucumber': 12, 'place_cucumber_into_bowl': 13, 'add_dressing': 14, 'mix_ingredients': 15, 'serve_salad_onto_plate': 16, 'action_start': 17, 'action_end': 18}
# num_classes argument: 19
# Full Train data size (before sampling): 458649
# Full Validation data size (before sampling): 118903
# Train data, size: 62255
# Test data, size: 11891
# Epoch 0 training: 100%|██████████| 1946/1946 [22:52<00:00,  1.42it/s]
# Epoch 0 testing: 100%|██████████| 372/372 [02:05<00:00,  2.97it/s]
# Epoch 0: Train Loss 25.1543, Train Top-1 Acc 0.3965%, Train Top-5 Acc 0.7094%, Test Loss 28.4472, Test Top-1 Acc 0.7860%, Test Top-5 Acc 0.9733%, Time 24.96 min, LR 1e-05
testing: 100%|██████████| 372/372 [02:03<00:00,  3.02it/s]
# Epoch 9: Train Loss 9.5419, Train Top-1 Acc 0.6164%, Train Top-5 Acc 0.7945%, Test Loss 27.2786, Test Top-1 Acc 0.8063%, Test Top-5 Acc 0.9617%, Time 255.02 min, LR 1e-05
# Epoch 10 training: 100%|██████████| 1946/1946 [22:31<00:00,  1.44it/s]
# Epoch 10 testing: 100%|██████████| 372/372 [02:03<00:00,  3.02it/s]
# Epoch 10: Train Loss 9.0545, Train Top-1 Acc 0.5964%, Train Top-5 Acc 0.7828%, Test Loss 25.1227, Test Top-1 Acc 0.8224%, Test Top-5 Acc 0.9688%, Time 279.60 min, LR 1.0000000000000002e-06
# Epoch 11 training: 100%|██████████| 1946/1946 [22:32<00:00,  1.44it/s]
# Epoch 11 testing: 100%|██████████| 372/372 [02:03<00:00,  3.02it/s]
# Epoch 11: Train Loss 8.7503, Train Top-1 Acc 0.6364%, Train Top-5 Acc 0.8080%, Test Loss 24.5447, Test Top-1 Acc 0.8210%, Test Top-5 Acc 0.9679%, Time 304.19 min, LR 1.0000000000000002e-06
# Epoch 12 training: 100%|██████████| 1946/1946 [22:32<00:00,  1.44it/s]
# Epoch 12 testing: 100%|██████████| 372/372 [02:03<00:00,  3.02it/s]
# Epoch 12: Train Loss 8.7725, Train Top-1 Acc 0.6058%, Train Top-5 Acc 0.7913%, Test Loss 25.1720, Test Top-1 Acc 0.8228%, Test Top-5 Acc 0.9670%, Time 328.78 min, LR 1.0000000000000002e-06
# Epoch 13 training: 100%|██████████| 1946/1946 [22:32<00:00,  1.44it/s]
# Epoch 13 testing: 100%|██████████| 372/372 [02:03<00:00,  3.02it/s]
# Epoch 13: Train Loss 8.2313, Train Top-1 Acc 0.6201%, Train Top-5 Acc 0.7944%, Test Loss 24.9845, Test Top-1 Acc 0.8233%, Test Top-5 Acc 0.9659%, Time 353.38 min, LR 1.0000000000000002e-07
# Epoch 14 training: 100%|██████████| 1946/1946 [22:32<00:00,  1.44it/s]
# Epoch 14 testing: 100%|██████████| 372/372 [02:03<00:00,  3.02it/s]
# Epoch 14: Train Loss 8.7662, Train Top-1 Acc 0.6281%, Train Top-5 Acc 0.8070%, Test Loss 24.7852, Test Top-1 Acc 0.8266%, Test Top-5 Acc 0.9658%, Time 377.99 min, LR 1.0000000000000002e-07
# Epoch 15 training: 100%|██████████| 1946/1946 [22:32<00:00,  1.44it/s]
# Epoch 15 testing: 100%|██████████| 372/372 [02:02<00:00,  3.03it/s]
# Epoch 15: Train Loss 8.5936, Train Top-1 Acc 0.6187%, Train Top-5 Acc 0.7992%, Test Loss 24.0294, Test Top-1 Acc 0.8281%, Test Top-5 Acc 0.9669%, Time 402.59 min, LR 1.0000000000000002e-07
# Epoch 16 training: 100%|██████████| 1946/1946 [22:30<00:00,  1.44it/s]
# Epoch 16 testing: 100%|██████████| 372/372 [02:17<00:00,  2.70it/s]
# Epoch 16: Train Loss 8.6614, Train Top-1 Acc 0.6063%, Train Top-5 Acc 0.7924%, Test Loss 24.2532, Test Top-1 Acc 0.8273%, Test Top-5 Acc 0.9675%, Time 427.39 min, LR 1.0000000000000004e-08
# Epoch 17 training: 100%|██████████| 1946/1946 [22:42<00:00,  1.43it/s]
# Epoch 17 testing: 100%|██████████| 372/372 [02:03<00:00,  3.02it/s]
# Epoch 17: Train Loss 8.5292, Train Top-1 Acc 0.6097%, Train Top-5 Acc 0.7905%, Test Loss 24.8934, Test Top-1 Acc 0.8255%, Test Top-5 Acc 0.9665%, Time 452.16 min, LR 1.0000000000000004e-08
# Epoch 18 training: 100%|██████████| 1946/1946 [22:29<00:00,  1.44it/s]
# Epoch 18 testing: 100%|██████████| 372/372 [02:02<00:00,  3.03it/s]
# Epoch 18: Train Loss 8.5289, Train Top-1 Acc 0.6087%, Train Top-5 Acc 0.7890%, Test Loss 24.7990, Test Top-1 Acc 0.8245%, Test Top-5 Acc 0.9654%, Time 476.70 min, LR 1.0000000000000004e-08
# Epoch 19 training: 100%|██████████| 1946/1946 [22:32<00:00,  1.44it/s]
# Epoch 19 testing: 100%|██████████| 372/372 [02:03<00:00,  3.02it/s]
# Epoch
# Epoch 28: Train Loss 8.4427, Train Top-1 Acc 0.6083%, Train Top-5 Acc 0.7919%, Test Loss 24.7090, Test Top-1 Acc 0.8285%, Test Top-5 Acc 0.9660%, Time 722.69 min, LR 1.0000000000000006e-11
# Epoch 29 training: 100%|██████████| 1946/1946 [22:48<00:00,  1.42it/s]
# Epoch 29 testing: 100%|██████████| 372/372 [02:05<00:00,  2.97it/s]
# Epoch 29: Train Loss 8.8574, Train Top-1 Acc 0.6165%, Train Top-5 Acc 0.8029%, Test Loss 24.7792, Test Top-1 Acc 0.8294%, Test Top-5 Acc 0.9653%, Time 747.59 min, LR 1.0000000000000006e-11
# Best Test Top-1 Accuracy: 0.829%
# Best Test Top-5 Accuracy: 0.973%

# %% [markdown]
# ---

# %% [markdown]
# # Testing

# %%
import pickle

maximum_top1_acc = test_accs_top1.index(max(test_accs_top1))

class_report, conf_matrix = loop(root="frames", 
                                index_cache="frames_index.txt", 
                                splits_file="splits.pkl", 
                                get_splits=f"split{split}_test", 
                                Is_train=False, 
                                local_model_path=f'{result_path}/Split{split}_{maximum_top1_acc}.pth',
                                epochs=False,
                                model_name=f'Split{split}', 
                                mapping='./mapping.txt')


results_file_pkl = f'{result_path}/split{split}_results.pkl'

results_dict = {
  'classification_report': class_report,
  'confusion_matrix': conf_matrix}

with open(results_file_pkl, 'wb') as f:
  pickle.dump(results_dict, f)
# Out:
# PyTorch Version: 2.3.1+cu118
# CUDA Available: True
# CUDA Version: 11.8
# cuDNN Version: 8700
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# VisionTransformer (VisionTransformer)                        [1, 3, 384, 384]     [1, 19]              768                  False
# ├─Conv2d (conv_proj)                                         [1, 3, 384, 384]     [1, 768, 24, 24]     (590,592)            False
# ├─Encoder (encoder)                                          [1, 577, 768]        [1, 577, 768]        443,136              False
# │    └─Dropout (dropout)                                     [1, 577, 768]        [1, 577, 768]        --                   --
# │    └─Sequential (layers)                                   [1, 577, 768]        [1, 577, 768]        --                   False
# │    │    └─EncoderBlock (encoder_layer_0)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_1)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_2)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_3)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_4)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_5)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_6)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_7)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_8)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_9)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_10)                  [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_11)                  [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    └─LayerNorm (ln)                                        [1, 577, 768]        [1, 577, 768]        (1,536)              False
# ├─Sequential (heads)                                         [1, 768]             [1, 19]              --                   False
# │    └─Dropout (0)                                           [1, 768]             [1, 768]             --                   --
# │    └─Linear (1)                                            [1, 768]             [1, 19]              (14,611)             False
# ============================================================================================================================================
# Total params: 86,105,107
# Trainable params: 0
# Non-trainable params: 86,105,107
# Total mult-adds (M): 396.90
# ============================================================================================================================================
# Input size (MB): 1.77
# Forward/backward pass size (MB): 304.87
# Params size (MB): 229.25
# Estimated Total Size (MB): 535.89
# ============================================================================================================================================
# Model loaded to cuda
# Loading samples from cache: frames_index.txt
#
# --- DEBUG: Total samples loaded into FrameDataset: 577552 ---
# Number of classes in dataset: 19 {'cut_tomato': 0, 'place_tomato_into_bowl': 1, 'cut_cheese': 2, 'place_cheese_into_bowl': 3, 'cut_lettuce': 4, 'place_lettuce_into_bowl': 5, 'add_salt': 6, 'add_vinegar': 7, 'add_oil': 8, 'add_pepper': 9, 'mix_dressing': 10, 'peel_cucumber': 11, 'cut_cucumber': 12, 'place_cucumber_into_bowl': 13, 'add_dressing': 14, 'mix_ingredients': 15, 'serve_salad_onto_plate': 16, 'action_start': 17, 'action_end': 18}
# num_classes argument: 19
# Full Train data size: 118903
# testing: 100%|██████████| 3716/3716 [19:08<00:00,  3.24it/s]
# Test Loss: 0.6875, Test Top-1 Acc: 0.8278, Test Top-5 Acc: 0.9667, Time 19.14 min
#
# Classification Report:
#
#                           precision    recall  f1-score   support
#
#               cut_tomato     0.8821    0.9458    0.9128     13546
#   place_tomato_into_bowl     0.8156    0.4672    0.5941      3570
#               cut_cheese     0.8778    0.9255    0.9010     11151
#   place_cheese_into_bowl     0.6385    0.4616    0.5358      2277
#              cut_lettuce     0.8226    0.9040    0.8614      8553
#  place_lettuce_into_bowl     0.5885    0.2970    0.3947      3492
#                 add_salt     0.9141    0.7814    0.8425      2205
#              add_vinegar     0.8602    0.9368    0.8968      4854
#                  add_oil     0.7955    0.9517    0.8666      5482
#               add_pepper     0.8157    0.7180    0.7637      2521
#             mix_dressing     0.7965    0.6025    0.6861      5029
#            peel_cucumber     0.9225    0.9020    0.9122     15052
#             cut_cucumber     0.7958    0.8334    0.8142      8236
# place_cucumber_into_bowl     0.6963    0.5458    0.6120      3512
#             add_dressing     0.4578    0.8667    0.5991      2798
#          mix_ingredients     0.7003    0.6710    0.6854      6627
#   serve_salad_onto_plate     0.8604    0.9358    0.8965      6607
#             action_start     0.9538    0.8458    0.8966      7368
#               action_end     0.8909    0.9696    0.9286      6023
#
#                 accuracy                         0.8278    118903
#                macro avg     0.7940    0.7664    0.7684    118903
#             weighted avg     0.8300    0.8278    0.8222    118903

# %% [markdown]
# ---

# %% [markdown]
# # Extracting per-class ACC

# %%
import pandas as pd

with open('./mapping.txt', 'r') as f:
    class_mappings = f.readlines()
class_names = [line.strip().split(' ', 1)[1] for line in class_mappings]
total_samples = conf_matrix.sum()

per_class_accuracy = {}
for idx, class_name in enumerate(class_names):
    TP = conf_matrix[idx, idx]  
    total_samples_per_class = conf_matrix[idx, :].sum()  # All samples of this class

    # Avoid division by zero
    if total_samples_per_class > 0:
        acc = TP / total_samples_per_class
    else:
        acc = 0  # If there are no samples, set accuracy to 0

    per_class_accuracy[class_name] = acc

    if class_name in class_report:
        class_report[class_name]['Accuracy'] = acc
  

class_report_pd = pd.DataFrame(class_report).T 
class_report_pd.columns=['precision', 'recall', 'f1-score', 'support', 'Accuracy']

class_report_pd.to_csv(f'{result_path}/Split{split}_report.csv')

# %%
Split = pd.read_csv(f'{result_path}/Split{split}_report.csv', index_col=0)
Split = Split[['Accuracy']][:20]
Split = Split.round(4)
Split
# Out:
#                           Accuracy
# cut_tomato                  0.9458
# place_tomato_into_bowl      0.4672
# cut_cheese                  0.9255
# place_cheese_into_bowl      0.4616
# cut_lettuce                 0.9040
# place_lettuce_into_bowl     0.2970
# add_salt                    0.7814
# add_vinegar                 0.9368
# add_oil                     0.9517
# add_pepper                  0.7180
# mix_dressing                0.6025
# peel_cucumber               0.9020
# cut_cucumber                0.8334
# place_cucumber_into_bowl    0.5458
# add_dressing                0.8667
# mix_ingredients             0.6710
# serve_salad_onto_plate      0.9358
# action_start                0.8458
# action_end                  0.9696
# accuracy                    0.8278
