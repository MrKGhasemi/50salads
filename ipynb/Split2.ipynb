# %% [markdown]
# # ```Split-2```

# %% [markdown]
# # Training

# %%
import gc
import torch

gc.collect()  # Force garbage collection to free up memory
torch.cuda.empty_cache()  # Optional but can help reduce memory pressure

# %%
import os
import warnings

# Ignore the specific warning about FlashAttention
warnings.filterwarnings(
    "ignore", 
    message="1Torch was not compiled with flash attention."
)

split = 2
result_path=f'./Split{split}_results'
os.makedirs(result_path, exist_ok=True)

# %%
from main import loop

# %%
test_accs_top1, test_accs_top5 = loop(root="frames", 
                                        index_cache="frames_index.txt", 
                                        splits_file="splits.pkl", 
                                        get_splits=[f"split{split}_train", f"split{split}_test"], 
                                        epochs=30,
                                        Is_train=True, 
                                        local_model_path=False, 
                                        model_name=f'Split{split}', 
                                        mapping=False)
# Out:
# PyTorch Version: 2.3.1+cu118
# CUDA Available: True
# CUDA Version: 11.8
# cuDNN Version: 8700
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# VisionTransformer (VisionTransformer)                        [1, 3, 384, 384]     [1, 19]              768                  Partial
# ├─Conv2d (conv_proj)                                         [1, 3, 384, 384]     [1, 768, 24, 24]     (590,592)            False
# ├─Encoder (encoder)                                          [1, 577, 768]        [1, 577, 768]        443,136              Partial
# │    └─Dropout (dropout)                                     [1, 577, 768]        [1, 577, 768]        --                   --
# │    └─Sequential (layers)                                   [1, 577, 768]        [1, 577, 768]        --                   Partial
# │    │    └─EncoderBlock (encoder_layer_0)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_1)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_2)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_3)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_4)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_5)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_6)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_7)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_8)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_9)                   [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_10)                  [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    │    └─EncoderBlock (encoder_layer_11)                  [1, 577, 768]        [1, 577, 768]        7,087,872            True
# │    └─LayerNorm (ln)                                        [1, 577, 768]        [1, 577, 768]        1,536                True
# ├─Sequential (heads)                                         [1, 768]             [1, 19]              --                   True
# │    └─Dropout (0)                                           [1, 768]             [1, 768]             --                   --
# │    └─Linear (1)                                            [1, 768]             [1, 19]              14,611               True
# ============================================================================================================================================
# Total params: 86,105,107
# Trainable params: 56,719,123
# Non-trainable params: 29,385,984
# Total mult-adds (M): 396.90
# ============================================================================================================================================
# Input size (MB): 1.77
# Forward/backward pass size (MB): 304.87
# Params size (MB): 229.25
# Estimated Total Size (MB): 535.89
# ============================================================================================================================================
# Model loaded to cuda
# Loading samples from cache: frames_index.txt
#
# --- DEBUG: Total samples loaded into FrameDataset: 577552 ---
# Number of classes in dataset: 19 {'cut_tomato': 0, 'place_tomato_into_bowl': 1, 'cut_cheese': 2, 'place_cheese_into_bowl': 3, 'cut_lettuce': 4, 'place_lettuce_into_bowl': 5, 'add_salt': 6, 'add_vinegar': 7, 'add_oil': 8, 'add_pepper': 9, 'mix_dressing': 10, 'peel_cucumber': 11, 'cut_cucumber': 12, 'place_cucumber_into_bowl': 13, 'add_dressing': 14, 'mix_ingredients': 15, 'serve_salad_onto_plate': 16, 'action_start': 17, 'action_end': 18}
# num_classes argument: 19
# Full Train data size (before sampling): 461597
# Full Validation data size (before sampling): 115955
# Train data, size: 64454
# Test data, size: 23191
# Epoch 0 training: 100%|██████████| 2015/2015 [24:06<00:00,  1.39it/s]
# Epoch 0 testing: 100%|██████████| 725/725 [03:58<00:00,  3.04it/s]
# Epoch 0: Train Loss 24.4563, Train Top-1 Acc 0.4014%, Train Top-5 Acc 0.7084%, Test Loss 41.9212, Test Top-1 Acc 0.7141%, Test Top-5 Acc 0.9398%, Time 28.09 min, LR 1e-05
# Epoch 1 training: 100%|██████████| 2015/2015 [24:09<00:00,  1.39it/s]
# Epoch 1 testing: 100%|██████████| 725/725 [03:58<00:00,  3.04it/s]
# Epoch 1: Train Loss 15.7183, Train Top-1 Acc 0.5100%, Train Top-5 Acc 0.7507%, Test Loss 37.8114, Test Top-1 Acc 0.7423%, Test Top-5 Acc 0.9507%, Time 56.23 min, LR 1e-05
# Epoch 2 training: 100%|██████████| 2015/2015 [24:09<00:00,  1.39it/s]
# Epoch 2 testing: 100%|██████████| 725/725 [03:58<00:00,  3.03it/s]
# Epoch 2: Train Loss 13.5179, Train Top-1 Acc 0.5537%, Train Top-5 Acc 0.7667%, Test Loss 38.0167, Test Top-1 Acc 0.7335%, Test Top-5 Acc 0.9559%, Time 84.38 min, LR 1e-05
# Epoch 3 training: 100%|██████████| 2015/2015 [24:08<00:00,  1.39it/s]
# Epoch 3 testing: 100%|██████████| 725/725 [03:58<00:00,  3.04it/s]
# Epoch 3: Train Loss 12.7795, Train Top-1 Acc 0.5686%, Train Top-5 Acc 0.7755%, Test Loss 34.4803, Test Top-1 Acc 0.7606%, Test Top-5 Acc 0.9538%, Time 112.51 min, LR 1e-05
# Epoch 4 training: 100%|██████████| 2015/2015 [24:09<00:00,  1.39it/s]
# Epoch 4 testing: 100%|██████████| 725/725 [04:00<00:00,  3.01it/s]
# Epoch 4: Train Loss 11.4636, Train Top-1 Acc 0.5709%, Train Top-5 Acc 0.7661%, Test Loss 37.2638, Test Top-1 Acc 0.7618%, Test Top-5 Acc 0.9600%, Time 140.68 min, LR 1e-05
# Epoch 5 training: 100%|██████████| 2015/2015 [24:15<00:00,  1.38it/s]
# Epoch 5 testing: 100%|██████████| 725/725 [03:58<00:00,  3.04it/s]
# Epoch 5: Train Loss 10.9015, Train Top-1 Acc 0.6061%, Train Top-5 Acc 0.7888%, Test Loss 36.2973, Test Top-1 Acc 0.7541%, Test Top-5 Acc 0.9655%, Time 168.93 min, LR 1e-05
# Epoch 6 training: 100%|██████████| 2015/2015 [24:08<00:00,  1.39it/s]
# Epoch 6 testing: 100%|██████████| 725/725 [04:03<00:00,  2.98it/s]
# Epoch 6: Train Loss 10.5476, Train Top-1 Acc 0.5890%, Train Top-5 Acc 0.7807%, Test Loss 34.3545, Test Top-1 Acc 0.7741%, Test Top-5 Acc 0.9607%, Time 197.14 min, LR 1e-05
# Epoch 7 training: 100%|██████████| 2015/2015 [25:49<00:00,  1.30it/s]
# Epoch 7 testing: 100%|██████████| 725/725 [04:33<00:00,  2.65it/s]
# Epoch 7: Train Loss 9.5008, Train Top-1 Acc 0.6101%, Train Top-5 Acc 0.7865%, Test Loss 31.6341, Test Top-1 Acc 0.7863%, Test Top-5 Acc 0.9639%, Time 227.54 min, LR 1.0000000000000002e-06
# Epoch 8 training: 100%|██████████| 2015/2015 [24:09<00:00,  1.39it/s]
# Epoch 8 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 8: Train Loss 9.1763, Train Top-1 Acc 0.6109%, Train Top-5 Acc 0.7881%, Test Loss 32.4037, Test Top-1 Acc 0.7878%, Test Top-5 Acc 0.9640%, Time 255.69 min, LR 1.0000000000000002e-06
# Epoch 9 training: 100%|██████████| 2015/2015 [24:10<00:00,  1.39it/s]
# Epoch 9 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 9: Train Loss 8.8620, Train Top-1 Acc 0.6118%, Train Top-5 Acc 0.7854%, Test Loss 32.5277, Test Top-1 Acc 0.7848%, Test Top-5 Acc 0.9611%, Time 283.86 min, LR 1.0000000000000002e-06
# Epoch 10 training: 100%|██████████| 2015/2015 [24:11<00:00,  1.39it/s]
# Epoch 10 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 10: Train Loss 8.9443, Train Top-1 Acc 0.6082%, Train Top-5 Acc 0.7861%, Test Loss 32.4425, Test Top-1 Acc 0.7869%, Test Top-5 Acc 0.9615%, Time 312.03 min, LR 1.0000000000000002e-06
# Epoch 11 training: 100%|██████████| 2015/2015 [24:10<00:00,  1.39it/s]
# Epoch 11 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 11: Train Loss 9.0249, Train Top-1 Acc 0.6197%, Train Top-5 Acc 0.7944%, Test Loss 32.0585, Test Top-1 Acc 0.7862%, Test Top-5 Acc 0.9626%, Time 340.21 min, LR 1.0000000000000002e-07
# Epoch 12 training: 100%|██████████| 2015/2015 [24:12<00:00,  1.39it/s]
# Epoch 12 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 12: Train Loss 8.8783, Train Top-1 Acc 0.6095%, Train Top-5 Acc 0.7860%, Test Loss 31.6873, Test Top-1 Acc 0.7880%, Test Top-5 Acc 0.9622%, Time 368.41 min, LR 1.0000000000000002e-07
# Epoch 13 training: 100%|██████████| 2015/2015 [24:11<00:00,  1.39it/s]
# Epoch 13 testing: 100%|██████████| 725/725 [04:07<00:00,  2.93it/s]
# Epoch 13: Train Loss 8.6354, Train Top-1 Acc 0.6236%, Train Top-5 Acc 0.7955%, Test Loss 32.0767, Test Top-1 Acc 0.7835%, Test Top-5 Acc 0.9623%, Time 396.73 min, LR 1.0000000000000002e-07
# Epoch 14 training: 100%|██████████| 2015/2015 [24:15<00:00,  1.38it/s]
# Epoch 14 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 14: Train Loss 9.0917, Train Top-1 Acc 0.6126%, Train Top-5 Acc 0.7928%, Test Loss 32.4060, Test Top-1 Acc 0.7870%, Test Top-5 Acc 0.9595%, Time 424.98 min, LR 1.0000000000000004e-08
# Epoch 15 training: 100%|██████████| 2015/2015 [26:13<00:00,  1.28it/s]
# Epoch 15 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 15: Train Loss 8.9184, Train Top-1 Acc 0.6119%, Train Top-5 Acc 0.7898%, Test Loss 31.9737, Test Top-1 Acc 0.7875%, Test Top-5 Acc 0.9605%, Time 455.19 min, LR 1.0000000000000004e-08
# Epoch 16 training: 100%|██████████| 2015/2015 [24:12<00:00,  1.39it/s]
# Epoch 16 testing: 100%|██████████| 725/725 [03:58<00:00,  3.04it/s]
# Epoch 16: Train Loss 9.1059, Train Top-1 Acc 0.6021%, Train Top-5 Acc 0.7850%, Test Loss 32.3700, Test Top-1 Acc 0.7865%, Test Top-5 Acc 0.9599%, Time 483.38 min, LR 1.0000000000000004e-08
# Epoch 17 training: 100%|██████████| 2015/2015 [24:11<00:00,  1.39it/s]
# Epoch 17 testing: 100%|██████████| 725/725 [03:58<00:00,  3.03it/s]
# Epoch 17: Train Loss 8.8454, Train Top-1 Acc 0.6087%, Train Top-5 Acc 0.7846%, Test Loss 32.0613, Test Top-1 Acc 0.7856%, Test Top-5 Acc 0.9619%, Time 511.56 min, LR 1.0000000000000005e-09
# Epoch 18 training: 100%|██████████| 2015/2015 [24:11<00:00,  1.39it/s]
# Epoch 18 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 18: Train Loss 8.7856, Train Top-1 Acc 0.6159%, Train Top-5 Acc 0.7900%, Test Loss 32.0284, Test Top-1 Acc 0.7870%, Test Top-5 Acc 0.9618%, Time 539.74 min, LR 1.0000000000000005e-09
# Epoch 19 training: 100%|██████████| 2015/2015 [24:11<00:00,  1.39it/s]
# Epoch 19 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 19: Train Loss 9.1422, Train Top-1 Acc 0.6005%, Train Top-5 Acc 0.7813%, Test Loss 32.2260, Test Top-1 Acc 0.7854%, Test Top-5 Acc 0.9613%, Time 567.93 min, LR 1.0000000000000005e-09
# Epoch 20 training: 100%|██████████| 2015/2015 [24:09<00:00,  1.39it/s]
# Epoch 20 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 20: Train Loss 8.8423, Train Top-1 Acc 0.6305%, Train Top-5 Acc 0.8003%, Test Loss 32.1583, Test Top-1 Acc 0.7861%, Test Top-5 Acc 0.9620%, Time 596.08 min, LR 1.0000000000000006e-10
# Epoch 21 training: 100%|██████████| 2015/2015 [24:10<00:00,  1.39it/s]
# Epoch 21 testing: 100%|██████████| 725/725 [04:00<00:00,  3.01it/s]
# Epoch 21: Train Loss 8.7963, Train Top-1 Acc 0.6188%, Train Top-5 Acc 0.7945%, Test Loss 31.9718, Test Top-1 Acc 0.7872%, Test Top-5 Acc 0.9608%, Time 624.26 min, LR 1.0000000000000006e-10
# Epoch 22 training: 100%|██████████| 2015/2015 [24:10<00:00,  1.39it/s]
# Epoch 22 testing: 100%|██████████| 725/725 [03:58<00:00,  3.03it/s]
# Epoch 22: Train Loss 9.2757, Train Top-1 Acc 0.6295%, Train Top-5 Acc 0.8040%, Test Loss 31.9285, Test Top-1 Acc 0.7862%, Test Top-5 Acc 0.9623%, Time 652.42 min, LR 1.0000000000000006e-10
# Epoch 23 training: 100%|██████████| 2015/2015 [24:10<00:00,  1.39it/s]
# Epoch 23 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 23: Train Loss 8.8088, Train Top-1 Acc 0.6140%, Train Top-5 Acc 0.7908%, Test Loss 32.2379, Test Top-1 Acc 0.7868%, Test Top-5 Acc 0.9612%, Time 680.59 min, LR 1.0000000000000006e-11
# Epoch 24 training: 100%|██████████| 2015/2015 [24:10<00:00,  1.39it/s]
# Epoch 24 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 24: Train Loss 9.0198, Train Top-1 Acc 0.5996%, Train Top-5 Acc 0.7829%, Test Loss 32.0819, Test Top-1 Acc 0.7856%, Test Top-5 Acc 0.9612%, Time 708.76 min, LR 1.0000000000000006e-11
# Epoch 25 training: 100%|██████████| 2015/2015 [24:15<00:00,  1.38it/s]
# Epoch 25 testing: 100%|██████████| 725/725 [03:58<00:00,  3.03it/s]
# Epoch 25: Train Loss 8.9710, Train Top-1 Acc 0.6252%, Train Top-5 Acc 0.7992%, Test Loss 32.3237, Test Top-1 Acc 0.7856%, Test Top-5 Acc 0.9609%, Time 737.00 min, LR 1.0000000000000006e-11
# Epoch 26 training: 100%|██████████| 2015/2015 [24:17<00:00,  1.38it/s]
# Epoch 26 testing: 100%|██████████| 725/725 [03:58<00:00,  3.03it/s]
# Epoch 26: Train Loss 8.7456, Train Top-1 Acc 0.6143%, Train Top-5 Acc 0.7911%, Test Loss 31.8565, Test Top-1 Acc 0.7877%, Test Top-5 Acc 0.9616%, Time 765.27 min, LR 1.0000000000000006e-11
# Epoch 27 training: 100%|██████████| 2015/2015 [24:14<00:00,  1.39it/s]
# Epoch 27 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 27: Train Loss 8.7622, Train Top-1 Acc 0.6056%, Train Top-5 Acc 0.7815%, Test Loss 31.9373, Test Top-1 Acc 0.7874%, Test Top-5 Acc 0.9608%, Time 793.50 min, LR 1.0000000000000006e-11
# Epoch 28 training: 100%|██████████| 2015/2015 [24:15<00:00,  1.38it/s]
# Epoch 28 testing: 100%|██████████| 725/725 [03:58<00:00,  3.03it/s]
# Epoch 28: Train Loss 9.1656, Train Top-1 Acc 0.6102%, Train Top-5 Acc 0.7947%, Test Loss 32.3036, Test Top-1 Acc 0.7872%, Test Top-5 Acc 0.9604%, Time 821.75 min, LR 1.0000000000000006e-11
# Epoch 29 training: 100%|██████████| 2015/2015 [24:15<00:00,  1.38it/s]
# Epoch 29 testing: 100%|██████████| 725/725 [03:59<00:00,  3.03it/s]
# Epoch 29: Train Loss 8.8931, Train Top-1 Acc 0.6190%, Train Top-5 Acc 0.7943%, Test Loss 32.0592, Test Top-1 Acc 0.7866%, Test Top-5 Acc 0.9630%, Time 850.01 min, LR 1.0000000000000006e-11
# Best Test Top-1 Accuracy: 0.788%
# Best Test Top-5 Accuracy: 0.965%

# %% [markdown]
# ---

# %% [markdown]
# # Testing

# %%
import pickle

maximum_top1_acc = test_accs_top1.index(max(test_accs_top1))

class_report, conf_matrix = loop(root="frames", 
                                index_cache="frames_index.txt", 
                                splits_file="splits.pkl", 
                                get_splits=f"split{split}_test", 
                                Is_train=False, 
                                local_model_path=f'{result_path}/Split{split}_{maximum_top1_acc}.pth',
                                epochs=False,
                                model_name=f'Split{split}', 
                                mapping='./mapping.txt')


results_file_pkl = f'{result_path}/split{split}_results.pkl'

results_dict = {
  'classification_report': class_report,
  'confusion_matrix': conf_matrix}

with open(results_file_pkl, 'wb') as f:
  pickle.dump(results_dict, f)
# Out:
# PyTorch Version: 2.3.1+cu118
# CUDA Available: True
# CUDA Version: 11.8
# cuDNN Version: 8700
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# VisionTransformer (VisionTransformer)                        [1, 3, 384, 384]     [1, 19]              768                  False
# ├─Conv2d (conv_proj)                                         [1, 3, 384, 384]     [1, 768, 24, 24]     (590,592)            False
# ├─Encoder (encoder)                                          [1, 577, 768]        [1, 577, 768]        443,136              False
# │    └─Dropout (dropout)                                     [1, 577, 768]        [1, 577, 768]        --                   --
# │    └─Sequential (layers)                                   [1, 577, 768]        [1, 577, 768]        --                   False
# │    │    └─EncoderBlock (encoder_layer_0)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_1)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_2)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_3)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_4)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_5)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_6)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_7)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_8)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_9)                   [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_10)                  [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    │    └─EncoderBlock (encoder_layer_11)                  [1, 577, 768]        [1, 577, 768]        (7,087,872)          False
# │    └─LayerNorm (ln)                                        [1, 577, 768]        [1, 577, 768]        (1,536)              False
# ├─Sequential (heads)                                         [1, 768]             [1, 19]              --                   False
# │    └─Dropout (0)                                           [1, 768]             [1, 768]             --                   --
# │    └─Linear (1)                                            [1, 768]             [1, 19]              (14,611)             False
# ============================================================================================================================================
# Total params: 86,105,107
# Trainable params: 0
# Non-trainable params: 86,105,107
# Total mult-adds (M): 396.90
# ============================================================================================================================================
# Input size (MB): 1.77
# Forward/backward pass size (MB): 304.87
# Params size (MB): 229.25
# Estimated Total Size (MB): 535.89
# ============================================================================================================================================
# Model loaded to cuda
# Loading samples from cache: frames_index.txt
#
# --- DEBUG: Total samples loaded into FrameDataset: 577552 ---
# Number of classes in dataset: 19 {'cut_tomato': 0, 'place_tomato_into_bowl': 1, 'cut_cheese': 2, 'place_cheese_into_bowl': 3, 'cut_lettuce': 4, 'place_lettuce_into_bowl': 5, 'add_salt': 6, 'add_vinegar': 7, 'add_oil': 8, 'add_pepper': 9, 'mix_dressing': 10, 'peel_cucumber': 11, 'cut_cucumber': 12, 'place_cucumber_into_bowl': 13, 'add_dressing': 14, 'mix_ingredients': 15, 'serve_salad_onto_plate': 16, 'action_start': 17, 'action_end': 18}
# num_classes argument: 19
# Full Train data size: 115955
# testing: 100%|██████████| 3624/3624 [19:13<00:00,  3.14it/s]
# Test Loss: 0.7574, Test Top-1 Acc: 0.7920, Test Top-5 Acc: 0.9674, Time 19.22 min
#
# Classification Report:
#
#                           precision    recall  f1-score   support
#
#               cut_tomato     0.9598    0.9074    0.9329     13915
#   place_tomato_into_bowl     0.6875    0.6283    0.6566      2413
#               cut_cheese     0.9185    0.8282    0.8710     10275
#   place_cheese_into_bowl     0.4983    0.6763    0.5738      2209
#              cut_lettuce     0.9038    0.7184    0.8005      9869
#  place_lettuce_into_bowl     0.5917    0.4644    0.5204      2855
#                 add_salt     0.9306    0.7953    0.8577      2413
#              add_vinegar     0.8700    0.9473    0.9070      4802
#                  add_oil     0.8964    0.8419    0.8683      6369
#               add_pepper     0.6675    0.7000    0.6834      2297
#             mix_dressing     0.7982    0.6057    0.6887      5295
#            peel_cucumber     0.7187    0.8976    0.7983     11821
#             cut_cucumber     0.7560    0.7880    0.7717      8242
# place_cucumber_into_bowl     0.4655    0.4692    0.4673      3195
#             add_dressing     0.9316    0.6847    0.7893      3781
#          mix_ingredients     0.5626    0.5286    0.5451      5653
#   serve_salad_onto_plate     0.6482    0.8914    0.7506      6650
#             action_start     0.7871    0.9571    0.8638      5597
#               action_end     0.9033    0.8627    0.8825      8304
#
#                 accuracy                         0.7920    115955
#                macro avg     0.7629    0.7470    0.7489    115955
#             weighted avg     0.8037    0.7920    0.7921    115955

# %% [markdown]
# ---

# %% [markdown]
# # Extracting per-class ACC

# %%
import pandas as pd

with open('./mapping.txt', 'r') as f:
    class_mappings = f.readlines()
class_names = [line.strip().split(' ', 1)[1] for line in class_mappings]
total_samples = conf_matrix.sum()

per_class_accuracy = {}
for idx, class_name in enumerate(class_names):
    TP = conf_matrix[idx, idx]  
    total_samples_per_class = conf_matrix[idx, :].sum()  # All samples of this class

    # Avoid division by zero
    if total_samples_per_class > 0:
        acc = TP / total_samples_per_class
    else:
        acc = 0  # If there are no samples, set accuracy to 0

    per_class_accuracy[class_name] = acc

    if class_name in class_report:
        class_report[class_name]['Accuracy'] = acc
  

class_report_pd = pd.DataFrame(class_report).T 
class_report_pd.columns=['precision', 'recall', 'f1-score', 'support', 'Accuracy']

class_report_pd.to_csv(f'{result_path}/Split{split}_report.csv')

# %%
Split = pd.read_csv(f'{result_path}/Split{split}_report.csv', index_col=0)
Split = Split[['Accuracy']][:20]
Split = Split.round(4)
Split
# Out:
#                           Accuracy
# cut_tomato                  0.9074
# place_tomato_into_bowl      0.6283
# cut_cheese                  0.8282
# place_cheese_into_bowl      0.6763
# cut_lettuce                 0.7184
# place_lettuce_into_bowl     0.4644
# add_salt                    0.7953
# add_vinegar                 0.9473
# add_oil                     0.8419
# add_pepper                  0.7000
# mix_dressing                0.6057
# peel_cucumber               0.8976
# cut_cucumber                0.7880
# place_cucumber_into_bowl    0.4692
# add_dressing                0.6847
# mix_ingredients             0.5286
# serve_salad_onto_plate      0.8914
# action_start                0.9571
# action_end                  0.8627
# accuracy                    0.7920
